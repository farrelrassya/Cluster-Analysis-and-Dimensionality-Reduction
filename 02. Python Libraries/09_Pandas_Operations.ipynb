# %% [markdown]
# <a href="https://colab.research.google.com/github/farrelrassya/Cluster-Analysis-and-Dimensionality-Reduction/blob/main/02.%20Python%20Libraries/09_Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Operations on single pandas data frames

# %%
import pandas as pd
import numpy as np

# %%
data_dict = {
    'total_bill': {0: 34.83, 1: 25.56, 2: 8.52, 3: 16.32, 4: 23.95, 5: 34.3},
    'tip': {0: 5.17, 1: 4.34, 2: 1.48, 3: 4.3, 4: 2.55, 5: 6.7},
    'smoker': {0: 'No', 1: 'No', 2: 'No', 3: 'Yes', 4: 'No', 5: 'No'},
    'day': {0: 'Thur', 1: 'Sun', 2: 'Thur', 3: 'Fri', 4: 'Sun', 5: 'Thur'}
}

df = pd.DataFrame(data_dict)

df
# Out:
#    total_bill   tip smoker   day
# 0       34.83  5.17     No  Thur
# 1       25.56  4.34     No   Sun
# 2        8.52  1.48     No  Thur
# 3       16.32  4.30    Yes   Fri
# 4       23.95  2.55     No   Sun
# 5       34.30  6.70     No  Thur

# %% [markdown]
# ### Summarization

# %%
df[['total_bill', 'tip']].sum()
# Out:
# total_bill    143.48
# tip            24.54
# dtype: float64

# %%
df[['total_bill', 'tip']].sum(axis = 0)
# Out:
# total_bill    143.48
# tip            24.54
# dtype: float64

# %%
df[['total_bill', 'tip']].sum(axis = 1)
# Out:
# 0    40.00
# 1    29.90
# 2    10.00
# 3    20.62
# 4    26.50
# 5    41.00
# dtype: float64

# %%
type(df[['total_bill', 'tip']].sum())
# Out:
# pandas.core.series.Series

# %%
df[['total_bill', 'tip']].sum(axis = 1).sum()
# Out:
# 168.02

# %%
df[['smoker', 'day']].nunique()
# Out:
# smoker    2
# day       3
# dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Thur', 'Sun', 'Fri'], dtype=object)

# %%
df[['day', 'smoker']].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e8b31ac0b1b5> in <cell line: 1>()
# ----> 1 df[['day', 'smoker']].unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df['day'].value_counts()
# Out:
# day
# Thur    3
# Sun     2
# Fri     1
# Name: count, dtype: int64

# %%
df[['day', 'smoker']].value_counts()
# Out:
# day   smoker
# Thur  No        3
# Sun   No        2
# Fri   Yes       1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        total_bill       tip
# count    6.000000  6.000000
# mean    23.913333  4.090000
# std     10.240925  1.858429
# min      8.520000  1.480000
# 25%     18.227500  2.987500
# 50%     24.755000  4.320000
# 75%     32.115000  4.962500
# max     34.830000  6.700000

# %%
df[['total_bill', 'tip']].describe().T
# Out:
#             count       mean        std   min      25%     50%      75%    max
# total_bill    6.0  23.913333  10.240925  8.52  18.2275  24.755  32.1150  34.83
# tip           6.0   4.090000   1.858429  1.48   2.9875   4.320   4.9625   6.70

# %% [markdown]
# ### Summarization with numpy

# %%
np.sum(df[['total_bill', 'tip']])
# Out:
# total_bill    143.48
# tip            24.54
# dtype: float64

# %%
np.sum(df[['total_bill', 'tip']], axis=1)
# Out:
# 0    40.00
# 1    29.90
# 2    10.00
# 3    20.62
# 4    26.50
# 5    41.00
# dtype: float64

# %%
df[['total_bill', 'tip']].to_numpy()
# Out:
# array([[34.83,  5.17],
#        [25.56,  4.34],
#        [ 8.52,  1.48],
#        [16.32,  4.3 ],
#        [23.95,  2.55],
#        [34.3 ,  6.7 ]])

# %% [markdown]
# ### Opperations on data frame elements

# %%
df
# Out:
#    total_bill   tip smoker   day
# 0       34.83  5.17     No  Thur
# 1       25.56  4.34     No   Sun
# 2        8.52  1.48     No  Thur
# 3       16.32  4.30    Yes   Fri
# 4       23.95  2.55     No   Sun
# 5       34.30  6.70     No  Thur

# %%
np.square(df[['total_bill', 'tip']])
# Out:
#    total_bill      tip
# 0   1213.1289  26.7289
# 1    653.3136  18.8356
# 2     72.5904   2.1904
# 3    266.3424  18.4900
# 4    573.6025   6.5025
# 5   1176.4900  44.8900

# %%
df['day'].str.upper()
# Out:
# 0    THUR
# 1     SUN
# 2    THUR
# 3     FRI
# 4     SUN
# 5    THUR
# Name: day, dtype: object

# %% [markdown]
# ### Opperations with single variables

# %%
df
# Out:
#    total_bill   tip smoker   day
# 0       34.83  5.17     No  Thur
# 1       25.56  4.34     No   Sun
# 2        8.52  1.48     No  Thur
# 3       16.32  4.30    Yes   Fri
# 4       23.95  2.55     No   Sun
# 5       34.30  6.70     No  Thur

# %%
df[['total_bill', 'tip']] + 10
# Out:
#    total_bill    tip
# 0       44.83  15.17
# 1       35.56  14.34
# 2       18.52  11.48
# 3       26.32  14.30
# 4       33.95  12.55
# 5       44.30  16.70

# %%
df[['smoker', 'day']] + 'AA'
# Out:
#   smoker     day
# 0   NoAA  ThurAA
# 1   NoAA   SunAA
# 2   NoAA  ThurAA
# 3  YesAA   FriAA
# 4   NoAA   SunAA
# 5   NoAA  ThurAA

# %% [markdown]
# ### Comparison operators

# %%
df
# Out:
#    total_bill   tip smoker   day
# 0       34.83  5.17     No  Thur
# 1       25.56  4.34     No   Sun
# 2        8.52  1.48     No  Thur
# 3       16.32  4.30    Yes   Fri
# 4       23.95  2.55     No   Sun
# 5       34.30  6.70     No  Thur

# %%
df[['total_bill', 'tip']] > 10
# Out:
#    total_bill    tip
# 0        True  False
# 1        True  False
# 2       False  False
# 3        True  False
# 4        True  False
# 5        True  False

# %%
df['total_bill'].between(20, 30)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# Name: total_bill, dtype: bool

# %%
df[['smoker', 'day']].isin(['No', 'Thur'])
# Out:
#    smoker    day
# 0    True   True
# 1    True  False
# 2    True   True
# 3   False  False
# 4    True  False
# 5    True   True

# %%
df['smoker'].str.contains('Y')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: smoker, dtype: bool

# %%
df[df['total_bill'].between(20, 30)]
# Out:
#    total_bill   tip smoker  day
# 1       25.56  4.34     No  Sun
# 4       23.95  2.55     No  Sun
