# %% [markdown]
# <a href="https://colab.research.google.com/github/farrelrassya/Cluster-Analysis-and-Dimensionality-Reduction/blob/main/02.%20Python%20Libraries/08_Pandas_Slicing_and_Modifying.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Slicing and modifying pandas data frames/series
#
# #### Lecture agenda :
#
# - Slicing pandas dataframes
# - Modifying pandas dataframes
# - Slicing pandas data series

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Slicing pandas dataframe

# %%
# Loading dataframe from a file

df = pd.read_csv(
    filepath_or_buffer='mall_customers.csv'
)

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Get single element

df.loc[0, 'Gender']
# Out:
# 'Male'

# %%
df.loc[0:1, 'Gender':'Annual Income (k$)']
# Out:
#   Gender  Age  Annual Income (k$)
# 0   Male   19                  15
# 1   Male   21                  15

# %%
df.loc[[0, 1], ['Gender', 'Annual Income (k$)']]
# Out:
#   Gender  Annual Income (k$)
# 0   Male                  15
# 1   Male                  15

# %%
# Get single row - returns pandas series

sub = df.loc[0, :]

print(type(sub))

sub
# Out:
# <class 'pandas.core.series.Series'>
# CustomerID                   1
# Gender                    Male
# Age                         19
# Annual Income (k$)          15
# Spending Score (1-100)      39
# Name: 0, dtype: object

# %%
# Get single row - returns pandas data frame

sub = df.loc[[0], :]

print(type(sub))

sub
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   Male   19                  15                      39

# %%
# Get multiple rows

sub_df = df.loc[[0,2], :]

sub_df
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 2           3  Female   20                  16                       6

# %%
# Get a single column - returns pandas series

df.loc[:, 'Age']
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
# Get a single column - returns df

sub_df = df.loc[:, ['Age']]

print(type(sub_df))
sub_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Age
# 0     19
# 1     21
# 2     20
# 3     23
# 4     31
# ..   ...
# 195   35
# 196   45
# 197   32
# 198   32
# 199   30
#
# [200 rows x 1 columns]

# %%
# Get multiple columns

sub_df = df.loc[:, ['Age', 'Gender']]

sub_df
# Out:
#      Age  Gender
# 0     19    Male
# 1     21    Male
# 2     20  Female
# 3     23  Female
# 4     31  Female
# ..   ...     ...
# 195   35  Female
# 196   45  Female
# 197   32    Male
# 198   32    Male
# 199   30    Male
#
# [200 rows x 2 columns]

# %%
# Get a single column - returns series

sub_df = df['Age']

print(type(sub_df))
sub_df
# Out:
# <class 'pandas.core.series.Series'>
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
# Get a single column - returns df

sub_df = df[['Age']]

print(type(sub_df))
sub_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Age
# 0     19
# 1     21
# 2     20
# 3     23
# 4     31
# ..   ...
# 195   35
# 196   45
# 197   32
# 198   32
# 199   30
#
# [200 rows x 1 columns]

# %%
# Get multiple columns

sub_df = df[['Age', 'Gender']]

sub_df
# Out:
#      Age  Gender
# 0     19    Male
# 1     21    Male
# 2     20  Female
# 3     23  Female
# 4     31  Female
# ..   ...     ...
# 195   35  Female
# 196   45  Female
# 197   32    Male
# 198   32    Male
# 199   30    Male
#
# [200 rows x 2 columns]

# %% [markdown]
# #### Slicing pandas data based on boolean expression

# %%
# Create new dataframe

data = {
    'A': [1, 2, 3, 4],
    'B': [5, 4, 3, 2],
    'C': ['a', 'b', 'c', 'd']
}

df = pd.DataFrame(data)

df
# Out:
#    A  B  C
# 0  1  5  a
# 1  2  4  b
# 2  3  3  c
# 3  4  2  d

# %%
bool_list_rows = [True, False, True, False]

# %%
# Slice based on boolean array

cols = ['A', 'B']

sliced_df = df.loc[bool_list_rows, cols]

sliced_df
# Out:
#    A  B
# 0  1  5
# 2  3  3

# %%
bool_list_cols = [True, True, False]

# %%
# Slice based on boolean array

sliced_df = df.loc[bool_list_rows, bool_list_cols]

sliced_df
# Out:
#    A  B
# 0  1  5
# 2  3  3

# %%
# Select both, rows and cols
# by using booleans

sliced_df = df[bool_list_rows]

sliced_df
# Out:
#    A  B  C
# 0  1  5  a
# 2  3  3  c

# %%
df['A'] > 2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: A, dtype: bool

# %%
# Slice based on single column condition

sliced_df = df[df['A'] > 2]
sliced_df
# Out:
#    A  B  C
# 2  3  3  c
# 3  4  2  d

# %%
sliced_df = sliced_df.reset_index(drop=True)

sliced_df
# Out:
#    A  B  C
# 0  3  3  c
# 1  4  2  d

# %% [markdown]
# #### Modifying pandas dataframe

# %%
# New data frame

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 32, 18],
}

df = pd.DataFrame(data)

df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   32
# 2  Charlie   18

# %%
# Modify single value

df.loc[1, 'Name'] = 'Alex'

df
# Out:
#       Name  Age
# 0    Alice   25
# 1     Alex   32
# 2  Charlie   18

# %%
# Modify entire row

df.loc[1, :] = ['Steve', 42]

df
# Out:
#       Name  Age
# 0    Alice   25
# 1    Steve   42
# 2  Charlie   18

# %%
# Modify whole column

df['Age'] = np.array([21, 22, 23])

df
# Out:
#       Name  Age
# 0    Alice   21
# 1    Steve   22
# 2  Charlie   23

# %%
# Modify whole column with constant

df['Age'] = 20

df
# Out:
#       Name  Age
# 0    Alice   20
# 1    Steve   20
# 2  Charlie   20

# %%
# Add new columns

df['proffesion'] = ['Engineer', 'Doctor', 'Actor']

df
# Out:
#       Name  Age proffesion
# 0    Alice   20   Engineer
# 1    Steve   20     Doctor
# 2  Charlie   20      Actor

# %%
# Add new values for a slice

df.loc[[0,1], ['Age', 'proffesion']] = [[25, 'Manager'], [30, 'Surgeon']]

df
# Out:
#       Name  Age proffesion
# 0    Alice   25    Manager
# 1    Steve   30    Surgeon
# 2  Charlie   20      Actor

# %%
# Adding pandas series as new column

new_series = pd.Series([30, 34 , 50])

print(new_series)

df['Age'] = new_series

df
# Out:
# 0    30
# 1    34
# 2    50
# dtype: int64
#       Name  Age proffesion
# 0    Alice   30    Manager
# 1    Steve   34    Surgeon
# 2  Charlie   50      Actor

# %%
# Adding dataframe as new columns / columns

new_df = pd.DataFrame([[True, False], [True, False], [False, False]], columns=['C1', 'C2'])
new_df
# Out:
#       C1     C2
# 0   True  False
# 1   True  False
# 2  False  False

# %%
df[['C1', 'C2']] = new_df
df
# Out:
#       Name  Age proffesion     C1     C2
# 0    Alice   30    Manager   True  False
# 1    Steve   34    Surgeon   True  False
# 2  Charlie   50      Actor  False  False

# %%
df[['A1', 'A2']] = new_df
df
# Out:
#       Name  Age proffesion     C1     C2     A1     A2
# 0    Alice   30    Manager   True  False   True  False
# 1    Steve   34    Surgeon   True  False   True  False
# 2  Charlie   50      Actor  False  False  False  False

# %%
new_df.index = [2,1,0]

new_df
# Out:
#       C1     C2
# 2   True  False
# 1   True  False
# 0  False  False

# %%
df[['D1', 'D2']] = new_df
df
# Out:
#       Name  Age proffesion     C1     C2     A1     A2     D1     D2
# 0    Alice   30    Manager   True  False   True  False  False  False
# 1    Steve   34    Surgeon   True  False   True  False   True  False
# 2  Charlie   50      Actor  False  False  False  False   True  False

# %%
new_df.index = [20,10,0]

df[['E1', 'E2']] = new_df
df
# Out:
#       Name  Age proffesion     C1     C2     A1     A2     D1     D2     E1  \
# 0    Alice   30    Manager   True  False   True  False  False  False  False
# 1    Steve   34    Surgeon   True  False   True  False   True  False    NaN
# 2  Charlie   50      Actor  False  False  False  False   True  False    NaN
#
#       E2
# 0  False
# 1    NaN
# 2    NaN

# %%
new_df.index = [20,10,0]

df[['K1', 'K2']] = new_df.to_numpy()
df
# Out:
#       Name  Age proffesion     C1     C2     A1     A2     D1     D2     E1  \
# 0    Alice   30    Manager   True  False   True  False  False  False  False
# 1    Steve   34    Surgeon   True  False   True  False   True  False    NaN
# 2  Charlie   50      Actor  False  False  False  False   True  False    NaN
#
#       E2     K1     K2
# 0  False   True  False
# 1    NaN   True  False
# 2    NaN  False  False

# %% [markdown]
# ### Slicing pandas data series

# %%
ds = pd.Series([30, 34 , 50, 33])

ds
# Out:
# 0    30
# 1    34
# 2    50
# 3    33
# dtype: int64

# %%
ds[0]
# Out:
# 30

# %%
ds[1:3]
# Out:
# 1    34
# 2    50
# dtype: int64

# %%
ds[[0,2]]
# Out:
# 0    30
# 2    50
# dtype: int64

# %%
ds[[True, False, False, True]]
# Out:
# 0    30
# 3    33
# dtype: int64
