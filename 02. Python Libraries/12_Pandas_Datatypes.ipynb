# %% [markdown]
# <a href="https://colab.research.google.com/github/farrelrassya/Cluster-Analysis-and-Dimensionality-Reduction/blob/main/02.%20Python%20Libraries/12_Pandas_Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas data types

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'Lists': [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
    'Sets': [{1, 2}, {3, 4}, {5, 6}],
    'Integers': [10, 20, 30],
    'Floats': [1.5, 2.5, 3.5],
    'Strings': ['a', 'b', 'c'],
    'Booleans': [True, False, True]
})

df
# Out:
#        Lists    Sets  Integers  Floats Strings  Booleans
# 0  [1, 2, 3]  {1, 2}        10     1.5       a      True
# 1  [4, 5, 6]  {3, 4}        20     2.5       b     False
# 2  [7, 8, 9]  {5, 6}        30     3.5       c      True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Lists     3 non-null      object
#  1   Sets      3 non-null      object
#  2   Integers  3 non-null      int64
#  3   Floats    3 non-null      float64
#  4   Strings   3 non-null      object
#  5   Booleans  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(3)
# memory usage: 251.0+ bytes

# %%
df.dtypes
# Out:
# Lists        object
# Sets         object
# Integers      int64
# Floats      float64
# Strings      object
# Booleans       bool
# dtype: object

# %%
print(df['Lists'].dtype)
# Out:
# object

# %%
df = pd.DataFrame(
    {
        'Integers': [10, 20, 30],
        'Floats': [1.5, 2.5, 3.5],
        'Booleans': [True, False, True]
    },
    dtype=np.float32
)

df
# Out:
#    Integers  Floats  Booleans
# 0      10.0     1.5       1.0
# 1      20.0     2.5       0.0
# 2      30.0     3.5       1.0

# %% [markdown]
# ### Dtype conversions

# %%
df = pd.DataFrame({
    'Lists': [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
    'Sets': [{1, 2}, {3, 4}, {5, 6}],
    'Integers': [10, 20, 30],
    'Floats': [1.5, 2.5, 3.5],
    'Strings': ['a', 'b', 'c'],
    'Booleans': [True, False, True]
})

df
# Out:
#        Lists    Sets  Integers  Floats Strings  Booleans
# 0  [1, 2, 3]  {1, 2}        10     1.5       a      True
# 1  [4, 5, 6]  {3, 4}        20     2.5       b     False
# 2  [7, 8, 9]  {5, 6}        30     3.5       c      True

# %%
df[['Booleans', 'Floats']].astype(int)
# Out:
#    Booleans  Floats
# 0         1       1
# 1         0       2
# 2         1       3

# %% [markdown]
# ### Mixed data type columns

# %%
df = pd.DataFrame([1, 2, 3, 'A'], columns=['col1'])

df
# Out:
#   col1
# 0    1
# 1    2
# 2    3
# 3    A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      object
# dtypes: object(1)
# memory usage: 160.0+ bytes

# %%
df['col1'] + df['col1']
# Out:
# 0     2
# 1     4
# 2     6
# 3    AA
# Name: col1, dtype: object

# %% [markdown]
# ### Getting columns based on data type

# %%
df = pd.DataFrame({
    'Lists': [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
    'Sets': [{1, 2}, {3, 4}, {5, 6}],
    'Integers': [10, 20, 30],
    'Floats': [1.5, 2.5, 3.5],
    'Strings': ['a', 'b', 'c'],
    'Booleans': [True, False, True]
})

df
# Out:
#        Lists    Sets  Integers  Floats Strings  Booleans
# 0  [1, 2, 3]  {1, 2}        10     1.5       a      True
# 1  [4, 5, 6]  {3, 4}        20     2.5       b     False
# 2  [7, 8, 9]  {5, 6}        30     3.5       c      True

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
numerical_columns
# Out:
# Index(['Integers', 'Floats'], dtype='object')
